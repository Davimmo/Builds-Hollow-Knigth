# %%
#Sem overcharged e yield
# Lista de amuletos mutuamente excludentes (pares)
exclusoes = [
    ("Coração Frágil", "Coração Inquebrável"),
    ("Ganância Frágil", "Ganância Inquebrável"),
    ("Força Frágil", "Força Inquebrável"),
    ("Criança Grimm", "Melodia Despreocupada"),
    ("Coração Vazio", "Alma do Rei")
]

def verificar_exclusoes(combinacao):
    # Verifica se a combinação contém pares mutuamente excludentes
    for a, b in exclusoes:
        if a in combinacao and b in combinacao:
            return False
    return True

def solv(charms, m, start=0, cc=None, cn=0):

    if cc is None:
        cc = []
    
    if cn == m:
        if "Coração Vazio" not in cc and "Alma do Rei" not in cc:
            if verificar_exclusoes(cc):
                yield cc + ["Coração Vazio"]
        else:
            yield cc
    
    if cn > m:
        return
    
    
    for i in range(start, len(charms)):
        name, notches = charms[i]
        if cn + notches > m:  # Aborta se somar exceder o limite
            continue
        
        # Adiciona o amuleto atual à combinação e continua a busca
        nova_combinacao = cc + [name]
        # Verifica se a combinação atual ainda é válida antes de continuar
        if verificar_exclusoes(nova_combinacao):
            yield from solv(charms, m, i + 1, nova_combinacao, cn + notches)

# Lista de amuletos e seus respectivos notches
charms = [
    ("Bússola Caprichosa", 1),
    ("Enxame de Colecionadores", 1),
    ("Carapaça Robusta", 2),
    ("Apanhador de Almas", 2),
    ("Pedra do Xamã", 3),
    ("Devorador de Almas", 4),
    ("Mestre da Esquiva", 2),
    ("Mestre da Corrida", 1),
    ("Canção das Larvas", 1),
    ("Elegia da Larvamosca", 3),
    ("Coração Frágil", 2),
    ("Coração Inquebrável", 2),
    ("Ganância Frágil", 2),
    ("Ganância Inquebrável", 2),
    ("Força Frágil", 3),
    ("Força Inquebrável", 3),
    ("Dobrador de Magias", 2),
    ("Corpo Firme", 1),
    ("Golpe Pesado", 2),
    ("Corte Rápido", 3),
    ("Ferrão Longo", 2),
    ("Marca de Orgulho", 3),
    ("Fúria dos Caídos", 2),
    ("Espinhos da Agonia", 1),
    ("Carapaça de Baldur", 2),
    ("Ninho de Flukes", 3),
    ("Insignia do Defensor", 1),
    ("Útero Brilhante", 2),
    ("Foco Rápido", 3),
    ("Foco Profundo", 4),
    ("Coração de Sangue Vital", 2),
    ("Núcleo de Sangue Vital", 3),
    ("Bênção de Joni", 4),
    ("Sangue da Colmeia", 4),
    ("Cogumelo com Esporos", 1),
    ("Sombra Afiada", 2),
    ("Forma de Unn", 2),
    ("Glória do Mestre do Ferrão", 1),
    ("Canção das Tecelãs", 2),
    ("Portador dos Sonhos", 1),
    ("Escudo dos Sonhos", 3),
    ("Criança Grimm", 2),
    ("Melodia Despreocupada", 3),
    ("Alma do Rei", 5)
]

# Gerando as combinações válidas
m = 11  # Máximo de notches
combinacoes_validas = list(solv(charms, m))
# Exibindo a quantidade de combinações válidas

print(f'Número total de combinações válidas: {len(combinacoes_validas):,}'.replace(',','.'))
# Out:
# Número total de combinações válidas: 1.840.147

# %%
#GPT com return
# Lista de amuletos mutuamente excludentes (pares)
exclusoes = [
    ("Coração Frágil", "Coração Inquebrável"),
    ("Ganância Frágil", "Ganância Inquebrável"),
    ("Força Frágil", "Força Inquebrável"),
    ("Criança Grimm", "Melodia Despreocupada"),
    ("Coração Vazio", "Alma do Rei")
]

def verificar_exclusoes(combinacao):
    # Verifica se a combinação contém pares mutuamente excludentes
    for a, b in exclusoes:
        if a in combinacao and b in combinacao:
            return False
    return True

def solv(charms, m, start=0, cc=None, cn=0):
    if cc is None:
        cc = []

    combinacoes = []  # Lista para armazenar as combinações válidas
    
    if cn == m:
        if "Coração Vazio" not in cc and "Alma do Rei" not in cc:
            if verificar_exclusoes(cc):
                combinacoes.append(cc + ["Coração Vazio"])
        else:
            combinacoes.append(cc)
    
    if cn > m:
        return combinacoes  # Retorna as combinações até o momento
    
    for i in range(start, len(charms)):
        name, notches = charms[i]
        if cn + notches > m:  # Aborta se somar exceder o limite
            continue
        
        # Adiciona o amuleto atual à combinação e continua a busca
        nova_combinacao = cc + [name]
        # Verifica se a combinação atual ainda é válida antes de continuar
        if verificar_exclusoes(nova_combinacao):
            combinacoes.extend(solv(charms, m, i + 1, nova_combinacao, cn + notches))
    
    return combinacoes  # Retorna todas as combinações válidas

# Lista de amuletos e seus respectivos notches
charms = [
    ("Bússola Caprichosa", 1),
    ("Enxame de Colecionadores", 1),
    ("Carapaça Robusta", 2),
    ("Apanhador de Almas", 2),
    ("Pedra do Xamã", 3),
    ("Devorador de Almas", 4),
    ("Mestre da Esquiva", 2),
    ("Mestre da Corrida", 1),
    ("Canção das Larvas", 1),
    ("Elegia da Larvamosca", 3),
    ("Coração Frágil", 2),
    ("Coração Inquebrável", 2),
    ("Ganância Frágil", 2),
    ("Ganância Inquebrável", 2),
    ("Força Frágil", 3),
    ("Força Inquebrável", 3),
    ("Dobrador de Magias", 2),
    ("Corpo Firme", 1),
    ("Golpe Pesado", 2),
    ("Corte Rápido", 3),
    ("Ferrão Longo", 2),
    ("Marca de Orgulho", 3),
    ("Fúria dos Caídos", 2),
    ("Espinhos da Agonia", 1),
    ("Carapaça de Baldur", 2),
    ("Ninho de Flukes", 3),
    ("Insignia do Defensor", 1),
    ("Útero Brilhante", 2),
    ("Foco Rápido", 3),
    ("Foco Profundo", 4),
    ("Coração de Sangue Vital", 2),
    ("Núcleo de Sangue Vital", 3),
    ("Bênção de Joni", 4),
    ("Sangue da Colmeia", 4),
    ("Cogumelo com Esporos", 1),
    ("Sombra Afiada", 2),
    ("Forma de Unn", 2),
    ("Glória do Mestre do Ferrão", 1),
    ("Canção das Tecelãs", 2),
    ("Portador dos Sonhos", 1),
    ("Escudo dos Sonhos", 3),
    ("Criança Grimm", 2),
    ("Melodia Despreocupada", 3),
    ("Alma do Rei", 5)
]

# Gerando as combinações válidas
m = 11  # Máximo de notches
combinacoes_validas = solv(charms, m)
# Exibindo a quantidade de combinações válidas
print(f"Número total de combinações válidas: {len(combinacoes_validas)}")

# Opcional: exibir algumas combinações
for combo in combinacoes_validas[:5]:  # Exibe as primeiras 5 combinações
    print(combo)
# Out:
# Número total de combinações válidas: 1840147
# ['Bússola Caprichosa', 'Enxame de Colecionadores', 'Carapaça Robusta', 'Apanhador de Almas', 'Pedra do Xamã', 'Mestre da Esquiva', 'Coração Vazio']
# ['Bússola Caprichosa', 'Enxame de Colecionadores', 'Carapaça Robusta', 'Apanhador de Almas', 'Pedra do Xamã', 'Mestre da Corrida', 'Canção das Larvas', 'Coração Vazio']
# ['Bússola Caprichosa', 'Enxame de Colecionadores', 'Carapaça Robusta', 'Apanhador de Almas', 'Pedra do Xamã', 'Mestre da Corrida', 'Corpo Firme', 'Coração Vazio']
# ['Bússola Caprichosa', 'Enxame de Colecionadores', 'Carapaça Robusta', 'Apanhador de Almas', 'Pedra do Xamã', 'Mestre da Corrida', 'Espinhos da Agonia', 'Coração Vazio']
# ['Bússola Caprichosa', 'Enxame de Colecionadores', 'Carapaça Robusta', 'Apanhador de Almas', 'Pedra do Xamã', 'Mestre da Corrida', 'Insignia do Defensor', 'Coração Vazio']

# %%
#Com overcharged
# Lista de amuletos mutuamente excludentes (pares)
exclusoes = [
    ("Coração Frágil", "Coração Inquebrável"),
    ("Ganância Frágil", "Ganância Inquebrável"),
    ("Força Frágil", "Força Inquebrável"),
    ("Criança Grimm", "Melodia Despreocupada"),
    ("Coração Vazio", "Alma do Rei")
]

def verificar_exclusoes(combinacao):
    # Verifica se a combinação contém pares mutuamente excludentes
    for a, b in exclusoes:
        if a in combinacao and b in combinacao:
            return False
    return True

def solv(charms, m, start=0, cc=None, cn=0):

    if cc is None:
        cc = []
    
    if cn == m:
        # Verifica se a combinação é válida
        if verificar_exclusoes(cc):
            for j in range(start, len(charms)):
                name, notches = charms[j]
                # Verifica se o amuleto tem slots >= 2
                if notches >= 2:
                    # Gera a nova combinação com o amuleto atual
                    nova_combinacao = cc + [name]
                    # Verifica se a nova combinação ainda é válida
                    if verificar_exclusoes(nova_combinacao):
                        # Se não tiver nem "Coração Vazio" nem "Alma do Rei", adiciona "Coração Vazio"
                        if "Coração Vazio" not in nova_combinacao and "Alma do Rei" not in nova_combinacao:
                            yield nova_combinacao + ["Coração Vazio"]
                        else:
                            yield nova_combinacao
        return
    
    if cn > m:
        return
    
    for i in range(start, len(charms)):
        name, notches = charms[i]
        if cn + notches > m:  # Aborta se somar exceder o limite
            continue
        # Adiciona o amuleto atual à combinação e continua a busca
        nova_combinacao = cc + [name]
        # Verifica se a combinação atual ainda é válida antes de continuar
        if verificar_exclusoes(nova_combinacao):
            yield from solv(charms, m, i + 1, nova_combinacao, cn + notches)

# Lista de amuletos e seus respectivos notches
charms = [
    ("Bússola Caprichosa", 1),
    ("Enxame de Colecionadores", 1),
    ("Carapaça Robusta", 2),
    ("Apanhador de Almas", 2),
    ("Pedra do Xamã", 3),
    ("Devorador de Almas", 4),
    ("Mestre da Esquiva", 2),
    ("Mestre da Corrida", 1),
    ("Canção das Larvas", 1),
    ("Elegia da Larvamosca", 3),
    ("Coração Frágil", 2),
    ("Coração Inquebrável", 2),
    ("Ganância Frágil", 2),
    ("Ganância Inquebrável", 2),
    ("Força Frágil", 3),
    ("Força Inquebrável", 3),
    ("Dobrador de Magias", 2),
    ("Corpo Firme", 1),
    ("Golpe Pesado", 2),
    ("Corte Rápido", 3),
    ("Ferrão Longo", 2),
    ("Marca de Orgulho", 3),
    ("Fúria dos Caídos", 2),
    ("Espinhos da Agonia", 1),
    ("Carapaça de Baldur", 2),
    ("Ninho de Flukes", 3),
    ("Insignia do Defensor", 1),
    ("Útero Brilhante", 2),
    ("Foco Rápido", 3),
    ("Foco Profundo", 4),
    ("Coração de Sangue Vital", 2),
    ("Núcleo de Sangue Vital", 3),
    ("Bênção de Joni", 4),
    ("Sangue da Colmeia", 4),
    ("Cogumelo com Esporos", 1),
    ("Sombra Afiada", 2),
    ("Forma de Unn", 2),
    ("Glória do Mestre do Ferrão", 1),
    ("Canção das Tecelãs", 2),
    ("Portador dos Sonhos", 1),
    ("Escudo dos Sonhos", 3),
    ("Criança Grimm", 2),
    ("Melodia Despreocupada", 3),
    ("Alma do Rei", 5)
]

# Gerando as combinações válidas
m = 10  # Máximo de notches
combinacoes_validas = list(solv(charms, m))

# Exibindo a quantidade de combinações válidas
print(f'Número total de combinações válidas: {len(combinacoes_validas):,}'.replace(',','.'))
# Out:
# Número total de combinações válidas: 4.096.707

# %%
#gerando combinação aleatória
from random import randint as rd
combinação=combinacoes_validas[rd(0,len(combinacoes_validas)-1)]
while "Pedra do Xamã" not in combinação or len(combinação)>7:
    combinação=combinacoes_validas[rd(0,len(combinacoes_validas)-1)]

print(combinação)
# Out:
# ['Bússola Caprichosa', 'Enxame de Colecionadores', 'Apanhador de Almas', 'Pedra do Xamã', 'Elegia da Larvamosca', 'Espinhos da Agonia', 'Coração Vazio']

# %% [markdown]
# ['Bússola Caprichosa', 'Sombra Afiada', 'Escudo dos Sonhos', 'Alma do Rei']
# ['Pedra do Xamã', 'Corpo Firme', 'Corte Rápido', 'Bênção de Joni', 'Coração Vazio']
# ['Bússola Caprichosa', 'Enxame de Colecionadores', 'Apanhador de Almas', 'Pedra do Xamã', 'Elegia da Larvamosca', 'Espinhos da Agonia', 'Coração Vazio']

# %%
#testar elementos repetidos
from collections import defaultdict

def verificar_primeiras_duplicatas(lista_de_listas, max_exemplos=5):
    # Dicionário para contar as listas
    contagem = defaultdict(int)
    exemplos_mostrados = 0  # Contador para o número de duplicatas exibidas
    
    # Normalizar (ordenar) e contar cada lista
    for lista in lista_de_listas:
        # Ordena a lista para ignorar a ordem dos elementos
        lista_ordenada = tuple(sorted(lista))  # Convertemos em tupla, pois listas não são "hashable"
        contagem[lista_ordenada] += 1
        
        # Exibir a duplicata se aparecer mais de uma vez
        if contagem[lista_ordenada] == 2:  # Conta só quando encontra a segunda ocorrência (primeira duplicata)
            print(f"Lista {lista_ordenada} apareceu pela segunda vez.")
            exemplos_mostrados += 1
        
        # Para após exibir as primeiras 5 duplicatas
        if exemplos_mostrados >= max_exemplos:
            break

    if exemplos_mostrados == 0:
        print("Nenhuma lista duplicada foi encontrada.")

# Exemplo de lista de listas
lista_de_listas = combinacoes_validas

verificar_primeiras_duplicatas(lista_de_listas, max_exemplos=5)

# %%
print(f'{(1840147+4096707):,}'.replace(',','.'))
# Out:
# 5.936.854
